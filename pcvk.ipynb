# %% [markdown]
# <a href="https://colab.research.google.com/github/davismaulana/PCVK_Genap_2024/blob/main/pcvk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-j9IUzHdJdxFvE-Px-IBYkWjEKIaM-3wkZA&s",
        "https://yt3.googleusercontent.com/Z77ne7hWy6V_uT0K-ejI80Ew-9mpEBuooDoY4RPc3j3EMbnELT04zLEBbGPjwzVIhFIsT7byHI8=s160-c-k-c0x00ffffff-no-rj",
        "https://avatars.githubusercontent.com/u/68956085?v=4"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image,(0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image,image_2))
  cv2_imshow(final_frame)
  print('\n')

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)

print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(tinggi):
    x = y
    if 0 <= x < lebar:
        image_3[y, x] = [255, 255, 255]

for y in range(tinggi):
    x = lebar - y - 1
    if 0 <= x < lebar:
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

start = 36
for y in range (45):
    for c in range (55):
        image_3[start + c,start + y] = [0,69,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

print('\n')

image = io.imread("https://i.pinimg.com/236x/77/53/d5/7753d514e0726b9c801fa89fd650ac5b.jpg")
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=168x150>
# <PIL.Image.Image image mode=RGB size=160x80>
# <PIL.Image.Image image mode=RGB size=400x200>
# resolusi image: tinggi x lebar =  200  x  200
# <PIL.Image.Image image mode=RGB size=200x200>
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=236x162>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

image = io.imread("https://i.pinimg.com/236x/77/53/d5/7753d514e0726b9c801fa89fd650ac5b.jpg")
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

start = 56
for y in range (45):
    for c in range (55):
        image_3[start + c,start + y] = [0,69,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=236x162>
